# %% [markdown]
# # Learning Score
# ## Introduction:
#  This notebook will read the excel files and calculated the difference of Z-score in 6 parameters with 'Day1-Day2', 'Day1-Day3', 'Day1-Day4', 'Day2-Day3', and 'Day2-Day4'.

# %%
import pandas as pd

# Excel File input path
excel_file_path = './d48_learning_score/d48_Learning_Score.xlsx'

# read data
data = pd.read_excel(excel_file_path, sheet_name= 'Z-score')

# %%
diff_z_score =  {'Name': [],
        'D1_D2_z_dist': [],
        'D1_D3_z_dist': [],
        'D1_D4_z_dist': [],
        'D2_D3_z_dist': [],
        'D2_D4_z_dist': [],
        'D1_D2_z_vel': [],
        'D1_D3_z_vel': [],
        'D1_D4_z_vel': [],
        'D2_D3_z_vel': [],
        'D2_D4_z_vel': [],
        'D1_D2_z_acc': [],
        'D1_D3_z_acc': [],
        'D1_D4_z_acc': [],
        'D2_D3_z_acc': [],
        'D2_D4_z_acc': [],
        'D1_D2_z_head_angle': [],
        'D1_D3_z_head_angle': [],
        'D1_D4_z_head_angle': [],
        'D2_D3_z_head_angle': [],
        'D2_D4_z_head_angle': [],
        'D1_D2_z_y_up': [],
        'D1_D3_z_y_up': [],
        'D1_D4_z_y_up': [],
        'D2_D3_z_y_up': [],
        'D2_D4_z_y_up': [],
        'D1_D2_z_y_mag': [],
        'D1_D3_z_y_mag': [],
        'D1_D4_z_y_mag': [],
        'D2_D3_z_y_mag': [],
        'D2_D4_z_y_mag': [],
        }
diff_z_score = pd.DataFrame(diff_z_score)
diff_z_score
# Out:
# Empty DataFrame
# Columns: [Name, D1_D2_z_dist, D1_D3_z_dist, D1_D4_z_dist, D2_D3_z_dist, D2_D4_z_dist, D1_D2_z_vel, D1_D3_z_vel, D1_D4_z_vel, D2_D3_z_vel, D2_D4_z_vel, D1_D2_z_acc, D1_D3_z_acc, D1_D4_z_acc, D2_D3_z_acc, D2_D4_z_acc, D1_D2_z_head_angle, D1_D3_z_head_angle, D1_D4_z_head_angle, D2_D3_z_head_angle, D2_D4_z_head_angle, D1_D2_z_y_up, D1_D3_z_y_up, D1_D4_z_y_up, D2_D3_z_y_up, D2_D4_z_y_up, D1_D2_z_y_mag, D1_D3_z_y_mag, D1_D4_z_y_mag, D2_D3_z_y_mag, D2_D4_z_y_mag]
# Index: []
#
# [0 rows x 31 columns]

# %%
# get the distinct fish id
diff_z_score['Name']= data['name'].unique()

m = len(diff_z_score['Name'])
n = len(data['name'])

# %% [markdown]
# ### Calculate the difference of dist

# %%
# set i j = 0
i = 0
j = 0
#parameter that you want to calculate
para = data['z_dist']
for i in range(0,n):
    for j in range(0,m):
        if diff_z_score['Name'][j] == data['name'][i]:
            #Get the value of day1
            if data['day'][i] == 1:
                day1 = para[i]
            if data['day'][i] == 2:
                day2 = para[i]
                diff_z_score['D1_D2_z_dist'][j] = abs(para[i]-day1)
            if data['day'][i] == 3:
                diff_z_score['D1_D3_z_dist'][j] = abs(para[i]-day1)
                diff_z_score['D2_D3_z_dist'][j] = abs(para[i]-day2)
            if data['day'][i] == 4:
                diff_z_score['D1_D4_z_dist'][j] = abs(para[i]-day1)
                diff_z_score['D2_D4_z_dist'][j] = abs(para[i]-day2)
# Out:
# <ipython-input-6-9448c139d216>:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   diff_z_score['D1_D2_z_dist'][j] = abs(para[i]-day1)
# <ipython-input-6-9448c139d216>:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   diff_z_score['D1_D3_z_dist'][j] = abs(para[i]-day1)
# <ipython-input-6-9448c139d216>:17: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   diff_z_score['D2_D3_z_dist'][j] = abs(para[i]-day2)
# ...

# %% [markdown]
# ### Calculate the difference of vel

# %%
# set i j = 0
i = 0
j = 0
#parameter that you want to calculate
para = data['z_vel']
for i in range(0,n):
    for j in range(0,m):
        if diff_z_score['Name'][j] == data['name'][i]:
            #Get the value of day1
            if data['day'][i] == 1:
                day1 = para[i]
            if data['day'][i] == 2:
                day2 = para[i]
                diff_z_score['D1_D2_z_vel'][j] = abs(para[i]-day1)
            if data['day'][i] == 3:
                diff_z_score['D1_D3_z_vel'][j] = abs(para[i]-day1)
                diff_z_score['D2_D3_z_vel'][j] = abs(para[i]-day2)
            if data['day'][i] == 4:
                diff_z_score['D1_D4_z_vel'][j] = abs(para[i]-day1)
                diff_z_score['D2_D4_z_vel'][j] = abs(para[i]-day2)
# Out:
# <ipython-input-7-ec3caeb101c8>:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   diff_z_score['D1_D2_z_vel'][j] = abs(para[i]-day1)
# <ipython-input-7-ec3caeb101c8>:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   diff_z_score['D1_D3_z_vel'][j] = abs(para[i]-day1)
# <ipython-input-7-ec3caeb101c8>:17: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   diff_z_score['D2_D3_z_vel'][j] = abs(para[i]-day2)
# ...

# %% [markdown]
# ### Calculate the difference of acc

# %%
# set i j = 0
i = 0
j = 0
#parameter that you want to calculate
para = data['z_acc']
for i in range(0,n):
    for j in range(0,m):
        if diff_z_score['Name'][j] == data['name'][i]:
            #Get the value of day1
            if data['day'][i] == 1:
                day1 = para[i]
            if data['day'][i] == 2:
                day2 = para[i]
                diff_z_score['D1_D2_z_acc'][j] = abs(para[i]-day1)
            if data['day'][i] == 3:
                diff_z_score['D1_D3_z_acc'][j] = abs(para[i]-day1)
                diff_z_score['D2_D3_z_acc'][j] = abs(para[i]-day2)
            if data['day'][i] == 4:
                diff_z_score['D1_D4_z_acc'][j] = abs(para[i]-day1)
                diff_z_score['D2_D4_z_acc'][j] = abs(para[i]-day2)
# Out:
# <ipython-input-8-4f4f7f4d7815>:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   diff_z_score['D1_D2_z_acc'][j] = abs(para[i]-day1)
# <ipython-input-8-4f4f7f4d7815>:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   diff_z_score['D1_D3_z_acc'][j] = abs(para[i]-day1)
# <ipython-input-8-4f4f7f4d7815>:17: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   diff_z_score['D2_D3_z_acc'][j] = abs(para[i]-day2)
# ...

# %% [markdown]
# ### Calculate the difference of head_angle

# %%
# set i j = 0
i = 0
j = 0
#parameter that you want to calculate
para = data['z_head_angle']
for i in range(0,n):
    for j in range(0,m):
        if diff_z_score['Name'][j] == data['name'][i]:
            #Get the value of day1
            if data['day'][i] == 1:
                day1 = para[i]
            if data['day'][i] == 2:
                day2 = para[i]
                diff_z_score['D1_D2_z_head_angle'][j] = abs(para[i]-day1)
            if data['day'][i] == 3:
                diff_z_score['D1_D3_z_head_angle'][j] = abs(para[i]-day1)
                diff_z_score['D2_D3_z_head_angle'][j] = abs(para[i]-day2)
            if data['day'][i] == 4:
                diff_z_score['D1_D4_z_head_angle'][j] = abs(para[i]-day1)
                diff_z_score['D2_D4_z_head_angle'][j] = abs(para[i]-day2)
# Out:
# <ipython-input-9-0c81bb014ad9>:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   diff_z_score['D1_D2_z_head_angle'][j] = abs(para[i]-day1)
# <ipython-input-9-0c81bb014ad9>:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   diff_z_score['D1_D3_z_head_angle'][j] = abs(para[i]-day1)
# <ipython-input-9-0c81bb014ad9>:17: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# ...

# %% [markdown]
# ### Calculate the difference of y_up

# %%
# set i j = 0
i = 0
j = 0
#parameter that you want to calculate
para = data['z_y_up']
for i in range(0,n):
    for j in range(0,m):
        if diff_z_score['Name'][j] == data['name'][i]:
            #Get the value of day1
            if data['day'][i] == 1:
                day1 = para[i]
            if data['day'][i] == 2:
                day2 = para[i]
                diff_z_score['D1_D2_z_y_up'][j] = abs(para[i]-day1)
            if data['day'][i] == 3:
                diff_z_score['D1_D3_z_y_up'][j] = abs(para[i]-day1)
                diff_z_score['D2_D3_z_y_up'][j] = abs(para[i]-day2)
            if data['day'][i] == 4:
                diff_z_score['D1_D4_z_y_up'][j] = abs(para[i]-day1)
                diff_z_score['D2_D4_z_y_up'][j] = abs(para[i]-day2)
# Out:
# <ipython-input-10-844fbe2790aa>:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   diff_z_score['D1_D2_z_y_up'][j] = abs(para[i]-day1)
# <ipython-input-10-844fbe2790aa>:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   diff_z_score['D1_D3_z_y_up'][j] = abs(para[i]-day1)
# <ipython-input-10-844fbe2790aa>:17: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   diff_z_score['D2_D3_z_y_up'][j] = abs(para[i]-day2)
# ...

# %% [markdown]
# ### Calculate the difference of y_mag

# %%
# set i j = 0
i = 0
j = 0
#parameter that you want to calculate
para = data['z_y_mag']
for i in range(0,n):
    for j in range(0,m):
        if diff_z_score['Name'][j] == data['name'][i]:
            #Get the value of day1
            if data['day'][i] == 1:
                day1 = para[i]
            if data['day'][i] == 2:
                day2 = para[i]
                diff_z_score['D1_D2_z_y_mag'][j] = abs(para[i]-day1)
            if data['day'][i] == 3:
                diff_z_score['D1_D3_z_y_mag'][j] = abs(para[i]-day1)
                diff_z_score['D2_D3_z_y_mag'][j] = abs(para[i]-day2)
            if data['day'][i] == 4:
                diff_z_score['D1_D4_z_y_mag'][j] = abs(para[i]-day1)
                diff_z_score['D2_D4_z_y_mag'][j] = abs(para[i]-day2)
# Out:
# <ipython-input-11-9d24d4385c5f>:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   diff_z_score['D1_D2_z_y_mag'][j] = abs(para[i]-day1)
# <ipython-input-11-9d24d4385c5f>:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   diff_z_score['D1_D3_z_y_mag'][j] = abs(para[i]-day1)
# <ipython-input-11-9d24d4385c5f>:17: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   diff_z_score['D2_D3_z_y_mag'][j] = abs(para[i]-day2)
# ...

# %%
# output as a csv file
diff_z_score.to_csv('d48_Difference_of_z_score.csv', index=False)
